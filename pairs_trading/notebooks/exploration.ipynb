# %% [markdown]
# # Exploratory scratch work
#
# Kept separate from the `pairs_trading` pipeline modules. Use this notebook for
# ad-hoc plots and checks (e.g. `data.plot_normalised_prices`); nothing here
# should be imported by the pipeline itself.

# %%
from pairs_trading import config, data

prices = data.load_all_candidate_prices()
data.plot_normalised_prices(prices)
